# %% [markdown]
# #Tests for finetuned models
# In this file 2 finetuned model will be tested. Llama 3.2 will be tested in both q8 and f16 quantization. 3 prompts will be used per run. After each run generation can be found as Markdown. Also all models will be pulled from HuggingFace. Links to repo is shared in references section of the report.

# %%
# !pip install llama-cpp-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 MB 10.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 2.6 MB/s eta 0:00:00
# ...
#   Created wheel for llama-cpp-python: filename=llama_cpp_python-0.3.6-cp311-cp311-linux_x86_64.whl size=4022151 sha256=369d51023cfe2f54ac48790e2d7c319403c4afed0575466ba96381eb0e0a48a2
#   Stored in directory: /root/.cache/pip/wheels/e8/96/d2/acfb576f7a58ef0580e2fec8096e5eefd17cc356017089337b
# Successfully built llama-cpp-python
# ...

# %%
from llama_cpp import Llama

# %%
from llama_cpp import Llama

finetuned_3_1_8B = Llama.from_pretrained(
	repo_id="Serdarbayraktar/llama3.1-8B-Fairytale",
	filename="unsloth.Q8_0.gguf",
)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# unsloth.Q8_0.gguf:   0%|          | 0.00/8.54G [00:00<?, ?B/s]
# llama_model_loader: loaded meta data with 30 key-value pairs and 292 tensors from /root/.cache/huggingface/hub/models--Serdarbayraktar--llama3.1-8B-Fairytale/snapshots/95e3d92e8aaf42a0c9eda0d013914d63eaba84f6/./unsloth.Q8_0.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# ...

# %%
finetuned_3_1_8B.create_chat_completion(
    messages=[
        {"role": "user", "content": "Give me a fairytale that teaches the importance of friendship with animals."}
    ]
)
# Out:
# llama_perf_context_print:        load time =   26023.38 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /    50 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   150 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =  191000.10 ms /   200 tokens
# {'id': 'chatcmpl-314f1812-d0e1-4412-b181-8c02353965b0',
#  'object': 'chat.completion',
#  'created': 1737404683,
#  'model': '/root/.cache/huggingface/hub/models--Serdarbayraktar--llama3.1-8B-Fairytale/snapshots/95e3d92e8aaf42a0c9eda0d013914d63eaba84f6/./unsloth.Q8_0.gguf',
#  'choices': [{'index': 0,
#    'message': {'role': 'assistant',
# ...

# %% [markdown]
# # Generation
# once upon a time there was a poor old man who had nothing in the world but a little dog , and that was very old and very poor . one day the dog ran away , and the old man was left all alone . he was so lonely that he could not bear it , and he went out into the fields to cry . as he was crying , he met a little girl who was crying too . she asked him why he was crying , and he told her that his dog had run away . she said that she had lost a little sister , and that she was crying because she could not find her . then the old man asked her to go home with him , and he would do the same for her as she had done for him

# %%
finetuned_3_1_8B.create_chat_completion(
    messages=[
        {"role": "user", "content": "Give me a fairytale that teaches betrayal in friendship with animals."}
    ]
)
# Out:
# Llama.generate: 38 prefix-match hit, remaining 11 prompt tokens to eval
# llama_perf_context_print:        load time =   26023.38 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /    11 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   204 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =  230944.32 ms /   215 tokens
# {'id': 'chatcmpl-bdf6f77a-6ba8-40ab-8d29-78bdbda5f0d5',
#  'object': 'chat.completion',
#  'created': 1737404983,
#  'model': '/root/.cache/huggingface/hub/models--Serdarbayraktar--llama3.1-8B-Fairytale/snapshots/95e3d92e8aaf42a0c9eda0d013914d63eaba84f6/./unsloth.Q8_0.gguf',
#  'choices': [{'index': 0,
#    'message': {'role': 'assistant',
# ...

# %% [markdown]
# #Generation
# once upon a time there was a poor man who had nothing to eat , and he had no money to buy food with . so he sent his son to the forest to hunt for something to eat . the son went into the forest and walked and walked until he came to a clearing . in the clearing stood a tree , and under the tree lay a great big bear . the bear was sleeping , and the boy was afraid to shoot him , for he was afraid that the bear might wake up and eat him . so he went around the tree and came to the other side , and there he saw a great big wolf . the wolf was sleeping , and the boy was afraid to shoot him , for he was afraid that the wolf might wake up and eat him . so he went around the tree again , and came to the other side , and there he saw a great big fox . the fox was sleeping , and the boy was afraid to shoot him , for he was afraid that the fox might wake up and eat him .

# %%
finetuned_3_1_8B.create_chat_completion(
    messages=[
        {"role": "user", "content": "Give me a fairytale that teaches violence to little childs. Use dog in fairytale."}
    ]
)
# Out:
# Llama.generate: 38 prefix-match hit, remaining 17 prompt tokens to eval
# llama_perf_context_print:        load time =   26023.38 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /    17 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   108 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =  135738.68 ms /   125 tokens
# {'id': 'chatcmpl-0557c62e-c294-499f-9b90-f4e61d1d6241',
#  'object': 'chat.completion',
#  'created': 1737405407,
#  'model': '/root/.cache/huggingface/hub/models--Serdarbayraktar--llama3.1-8B-Fairytale/snapshots/95e3d92e8aaf42a0c9eda0d013914d63eaba84f6/./unsloth.Q8_0.gguf',
#  'choices': [{'index': 0,
#    'message': {'role': 'assistant',
# ...

# %% [markdown]
# #Generation
# once upon a time there was a little boy and a little girl , and they were brother and sister . they were very fond of one another , and they used to play together all day long . one day , as they were playing together , they came to a great forest . they had never seen a forest before , and they were both very much frightened . the little boy was afraid of the trees , and the little girl was afraid of the wild beasts . they did not know what to do , and they did not know where to go .

# %% [markdown]
# #other mdoe

# %%
finetuned_3_2_3B = Llama.from_pretrained(
	repo_id="Serdarbayraktar/llama3.2-3B-Fairytale",
	filename="unsloth.Q8_0.gguf",
)
# Out:
# unsloth.Q8_0.gguf:   0%|          | 0.00/3.42G [00:00<?, ?B/s]
# llama_model_loader: loaded meta data with 30 key-value pairs and 255 tensors from /root/.cache/huggingface/hub/models--Serdarbayraktar--llama3.2-3B-Fairytale/snapshots/42d5ed43ca56f13e41399e9f48d9441669153ffc/./unsloth.Q8_0.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.type str              = model
# llama_model_loader: - kv   2:                               general.name str              = Llama 3.2 3b Instruct Bnb 4bit
# llama_model_loader: - kv   3:                       general.organization str              = Unsloth
# llama_model_loader: - kv   4:                           general.finetune str              = instruct-bnb-4bit
# ...

# %%
finetuned_3_2_3B.create_chat_completion(
    messages=[
        {"role": "user", "content": "Give me a fairytale that teaches the importance of friendship with animals."}
    ]
)
# Out:
# llama_perf_context_print:        load time =    6694.30 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /    50 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   461 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =  235764.34 ms /   511 tokens
# {'id': 'chatcmpl-e40de3a8-f95b-4098-a59a-950e2689128e',
#  'object': 'chat.completion',
#  'created': 1737406107,
#  'model': '/root/.cache/huggingface/hub/models--Serdarbayraktar--llama3.2-3B-Fairytale/snapshots/42d5ed43ca56f13e41399e9f48d9441669153ffc/./unsloth.Q8_0.gguf',
#  'choices': [{'index': 0,
#    'message': {'role': 'assistant',
# ...

# %% [markdown]
# #Generation
# once upon a time there was a little girl who lived in a small cottage with her mother . she was very fond of her mother , but she was not fond of her step - father , who was a cruel and wicked man . he was always beating her and making her do hard work . one day she went out into the forest to pick berries , and she met a little rabbit who asked her to come home with him . she said yes , and they went together , and the rabbit showed her all the wonders of the forest . she was so happy that she forgot all about her step - father . but when she got home she found that her step - father had beaten her mother , and that she was now ill . she was so sorry that she had forgotten her mother that she begged the rabbit to take her back . he said yes , and they went home together , and the rabbit showed her all the wonders of the forest again . she was so happy that she forgot all about her step - father . but when she got home she found that her step - father had beaten her mother again , and that she was now worse . she was so sorry that she had forgotten her mother that she begged the rabbit to take her back . he said yes , and they went home together , and the rabbit showed her all the wonders of the forest again . she was so happy that she forgot all about her step - father . but when she got home she found that her step - father had beaten her mother again , and that she was now ill . she was so sorry that she had forgotten her mother that she begged the rabbit to take her back . he said yes , and they went home together , and the rabbit showed her all the wonders of the forest again . she was so happy that she forgot all about her step - father . but when she got home she found that her step - father had beaten her mother again , and that she was now worse . she was so sorry that she had forgotten her mother that she begged the rabbit to take her back . he said yes , and they went home together , and the rabbit showed her all the wonders of the forest again . she was so happy that she forgot all about her step - father . but when she got home she found that her step - father had beaten her

# %%
finetuned_3_2_3B.create_chat_completion(
    messages=[
        {"role": "user", "content": "Give me a fairytale that teaches betrayal in friendship with animals."}
    ]
)
# Out:
# Llama.generate: 38 prefix-match hit, remaining 11 prompt tokens to eval
# llama_perf_context_print:        load time =    6694.30 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /    11 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   462 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =  236965.72 ms /   473 tokens
# {'id': 'chatcmpl-c69863e6-4178-4325-8007-a81814960411',
#  'object': 'chat.completion',
#  'created': 1737406343,
#  'model': '/root/.cache/huggingface/hub/models--Serdarbayraktar--llama3.2-3B-Fairytale/snapshots/42d5ed43ca56f13e41399e9f48d9441669153ffc/./unsloth.Q8_0.gguf',
#  'choices': [{'index': 0,
#    'message': {'role': 'assistant',
# ...

# %% [markdown]
# #Generation
# once upon a time there lived a fox and a wolf . the fox was very cunning , and the wolf was very strong . they were the best of friends , and they lived together in a little cottage . they had a great deal of fun together , and they were very fond of each other . one day the fox said to the wolf , " i have a great idea . i have heard of a beautiful princess who lives in a castle at the end of the forest , and i have decided to go and see her . " " oh , what a wonderful thing ! " said the wolf . " i will come with you . " " no , no , " said the fox , " you will not come with me . i do not want you to come with me . " " why not ? " said the wolf . " i do not want you to come with me , " said the fox , " because i do not want you to see the princess . " " what do you mean ? " said the wolf . " i mean that i do not want you to see her , " said the fox . " i have a great idea , and i do not want you to know it . " " oh , i see ! " said the wolf . " you are afraid that i will go and see the princess , and you do not want me to do so . " " yes , that is it ! " said the fox . " i do not want you to see her . " " i will not see her , " said the wolf . " i will not see her . " " no , no , " said the fox . " you will not see her . " " i will not see her , " said the wolf . " i will not see her . " " no , no , " said the fox . " you will not see her . " " i will not see her , " said the wolf . " i will not see her . " " no , no , " said the fox . " you will not see her . " " i will not see her , " said the wolf . " i will not see her . " " no , no , " said the fox . " you will not see her . " " i will not see her , " said the wolf . "

# %%
finetuned_3_2_3B.create_chat_completion(
    messages=[
        {"role": "user", "content": "Give me a fairytale that teaches violence to little childs. Use dog in fairytale."}
    ]
)
# Out:
# Llama.generate: 38 prefix-match hit, remaining 17 prompt tokens to eval
# llama_perf_context_print:        load time =    6694.30 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /    17 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   456 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =  229407.26 ms /   473 tokens
# {'id': 'chatcmpl-e615ce33-03c6-4fce-82ff-f2e24d219e49',
#  'object': 'chat.completion',
#  'created': 1737406580,
#  'model': '/root/.cache/huggingface/hub/models--Serdarbayraktar--llama3.2-3B-Fairytale/snapshots/42d5ed43ca56f13e41399e9f48d9441669153ffc/./unsloth.Q8_0.gguf',
#  'choices': [{'index': 0,
#    'message': {'role': 'assistant',
# ...

# %% [markdown]
# #Generation
#
# once upon a time there was a little girl named katerina , who lived in a small cottage with her mother and father . she was a very good girl , and always did her best to help her parents . but she was very fond of dogs , and had a little dog of her own , whose name was misha . misha was a very good dog , and loved katerina very much . he was always by her side , and never left her . one day , while katerina was out in the garden , misha ran out and met a big , ugly dog , who was very fond of biting . the dog was named gromov , and he was very cruel . he had been sent by a wicked old woman to do harm to katerina . he bit misha on the nose , and then ran away . katerina was very sad , and she cried and cried . she did not know what to do . she went to her mother and father , and told them what had happened . they were very angry , and they said that they would go and find gromov , and make him pay for what he had done . they went to the old woman 's house , and asked her to tell them what she had done . the old woman said that she had sent gromov to bite misha , and that he was a very bad dog . katerina 's parents were very angry , and they said that they would make gromov pay for what he had done . they went to the old woman 's house , and asked her to give them gromov . the old woman said that she would give him to them , but that they must first give her something in return . katerina 's parents gave her a little bag of sugar , and the old woman gave them gromov . they took him home , and put him in a cage . katerina was very glad to have gromov back , and she loved him very much . she gave him plenty of food and water , and she played with him every day . but gromov was very cruel , and he bit katerina 's parents on the nose . they were very angry , and they said that they would make g

# %%
finetuned_3_2_3B_F16 = Llama.from_pretrained(
	repo_id="Serdarbayraktar/llama3.2-3B-Fairytale",
	filename="unsloth.F16.gguf",
)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# unsloth.F16.gguf:   0%|          | 0.00/6.43G [00:00<?, ?B/s]
# llama_model_loader: loaded meta data with 30 key-value pairs and 255 tensors from /root/.cache/huggingface/hub/models--Serdarbayraktar--llama3.2-3B-Fairytale/snapshots/42d5ed43ca56f13e41399e9f48d9441669153ffc/./unsloth.F16.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# ...

# %%
finetuned_3_2_3B_F16.create_chat_completion(
    messages=[
        {"role": "user", "content": "Give me a fairytale that teaches the importance of friendship with animals."}
    ]
)
# Out:
# llama_perf_context_print:        load time =   10416.00 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /    50 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   461 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =  507458.16 ms /   511 tokens
# {'id': 'chatcmpl-05d5d69f-ed80-4ed8-85d4-ccb1c09e8478',
#  'object': 'chat.completion',
#  'created': 1737500460,
#  'model': '/root/.cache/huggingface/hub/models--Serdarbayraktar--llama3.2-3B-Fairytale/snapshots/42d5ed43ca56f13e41399e9f48d9441669153ffc/./unsloth.F16.gguf',
#  'choices': [{'index': 0,
#    'message': {'role': 'assistant',
# ...

# %% [markdown]
# #Generation
# once upon a time there was a little girl who lived in a small cottage with her mother . she was very fond of her mother , but she was not fond of her step - father , who was a cruel and wicked man . he was always beating her and making her do hard work . she was very sad and lonely , and longed for a friend to talk to . one day she went out into the forest to pick wild flowers , and she met a little rabbit who was very friendly and kind . he asked her what she was doing , and she told him that she was picking wild flowers for her mother . the rabbit said , " i will help you pick them , and then i will take you to see my mother . she is a kind and gentle rabbit , and she will be very fond of you . " he picked the flowers for her , and then he led her to his mother \'s burrow . the mother rabbit was very kind to her , and she gave her a little basket of fresh flowers . the little girl was so happy that she thanked the rabbit and promised to visit him again . she went home to her step - father , and told him that she had met a kind rabbit who had helped her pick wild flowers . he was very angry and said , " if you do not stop talking about that rabbit , i will beat you . " but the little girl was not afraid , for she knew that the rabbit was her friend . she went to the forest again the next day , and the rabbit met her and took her to see his mother . the mother rabbit was very kind to her , and she gave her a little basket of fresh flowers . the little girl was so happy that she thanked the rabbit and promised to visit him again . she went home to her step - father , and told him that she had met a kind rabbit who had helped her pick wild flowers . he was very angry and said , " if you do not stop talking about that rabbit , i will beat you . " but the little girl was not afraid , for she knew that the rabbit was her friend . she went to the forest again the next day , and the rabbit met her and took her to see his mother . the mother rabbit was very kind to her , and she gave her a little basket of fresh

# %%
finetuned_3_2_3B_F16.create_chat_completion(
    messages=[
        {"role": "user", "content": "Give me a fairytale that teaches betrayal in friendship with animals."}
    ]
)
# Out:
# Llama.generate: 38 prefix-match hit, remaining 11 prompt tokens to eval
# llama_perf_context_print:        load time =   10416.00 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /    11 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   462 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time